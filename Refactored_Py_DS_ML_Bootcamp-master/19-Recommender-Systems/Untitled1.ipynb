# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
res=pd.read_csv('new_york.txt',sep='\t',names=['id','name','feat_id'])

# %%
res
# Out:
#         id                  name  \
# 0        0              Natalino
# 1        1           Indian Cafe
# 2        2  Manhattan Plaza Cafe
# 3        3          The Stanhope
# 4        4         Chez Napoleon
# ...    ...                   ...
# 1195  1195                  Ecco
# 1196  1196      Pierre au Tunnel
# 1197  1197            Honmura An
# 1198  1198          Shinbashi-an
# 1199  1199       Mickey Mantle's
#
#                                                 feat_id
# 0                                   125 075 205 052 167
# 1                                   117 075 205 052 164
# 2     100 086 250 196 191 192 063 111 059 231 224 00...
# 3       113 196 193 040 097 224 045 091 075 206 054 168
# 4                               193 092 075 205 052 167
# ...                                                 ...
# 1195                        229 125 140 075 205 053 167
# 1196                        193 248 092 075 205 053 167
# ...

# %%
features=pd.read_csv('features.txt',sep='\t',names=['feat_id','feature'])

# %%
def func(a):
    print(a[0])

# %%
# Out:
# 0
# Natalino
# 125 075 205 052 167
# id         None
# name       None
# feat_id    None
# dtype: object

# %%
res
# Out:
#         id                  name  \
# 0        0              Natalino
# 1        1           Indian Cafe
# 2        2  Manhattan Plaza Cafe
# 3        3          The Stanhope
# 4        4         Chez Napoleon
# ...    ...                   ...
# 1195  1195                  Ecco
# 1196  1196      Pierre au Tunnel
# 1197  1197            Honmura An
# 1198  1198          Shinbashi-an
# 1199  1199       Mickey Mantle's
#
#                                                 feat_id
# 0                                   125 075 205 052 167
# 1                                   117 075 205 052 164
# 2     100 086 250 196 191 192 063 111 059 231 224 00...
# 3       113 196 193 040 097 224 045 091 075 206 054 168
# 4                               193 092 075 205 052 167
# ...                                                 ...
# 1195                        229 125 140 075 205 053 167
# 1196                        193 248 092 075 205 053 167
# ...
